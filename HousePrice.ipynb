# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.nunique()
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.bar(df['bedrooms'] , df['price'])
plt.title("Scatter Plot")
plt.xlabel('Bed Rooms')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(df['bedrooms'] , df['price'])
plt.title("Scatter Plot")
plt.xlabel('Bed Rooms')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(df['price'] , df['sqft_living'])
plt.xlabel('Price')
plt.ylabel('Sq Ft Living')
plt.show()

# %% [markdown]
# # Model Building

# %%
features = df.drop(['price', 'id'] , axis=1)
label = df['price']
features
# Out:
#        date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0         0         3       1.00         1180      5650     1.0           0
# 1         0         3       2.25         2570      7242     2.0           0
# 2         0         2       1.00          770     10000     1.0           0
# 3         0         4       3.00         1960      5000     1.0           0
# 4         0         3       2.00         1680      8080     1.0           0
# ...     ...       ...        ...          ...       ...     ...         ...
# 21608     0         3       2.50         1530      1131     3.0           0
# 21609     0         4       2.50         2310      5813     2.0           0
# 21610     0         2       0.75         1020      1350     2.0           0
# 21611     0         3       2.50         1600      2388     2.0           0
# 21612     0         2       0.75         1020      1076     2.0           0
#
# ...

# %%
conv_dates = [1 if values == 2014 else 0 for values in data.date ]
features['date'] = conv_dates

# %%
features.head()
# Out:
#    date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0     0         3       1.00         1180      5650     1.0           0     0
# 1     0         3       2.25         2570      7242     2.0           0     0
# 2     0         2       1.00          770     10000     1.0           0     0
# 3     0         4       3.00         1960      5000     1.0           0     0
# 4     0         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
label.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train , X_test , y_train , y_test = train_test_split(features, label , test_size=0.2)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
gbr.score(X_test, y_test)
# Out:
# 0.8496906950238226

# %%
gbr.predict([[0,3,2.00,1680,8080,1.0,0,0,3,8,1680,0,1987,0,98074,47.6168,-122.045,1800,7503]])
# Out:
# C:\Users\Ram kumar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([551047.18208176])
